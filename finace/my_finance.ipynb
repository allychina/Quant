# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import datetime as dt
from matplotlib import style

# %%
style.use('ggplot')

# %%
start = dt.datetime(2000,1,1)
end = dt.datetime(2018,7,26)

# %%
df = web.DataReader('TSLA','yahoo',start=start,end=end)

# %%
df.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Close</th>
#       <th>Adj Close</th>
#       <th>Volume</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-06-29</th>
#       <td>19.000000</td>
#       <td>25.00</td>
#       <td>17.540001</td>
#       <td>23.889999</td>
#       <td>23.889999</td>
#       <td>18766300</td>
#     </tr>
#     <tr>
#       <th>2010-06-30</th>
#       <td>25.790001</td>
#       <td>30.42</td>
# ...

# %%
df.plot()

# %%
plt.show()

# %%
df[['Open','Close']].plot()
plt.show()

# %%
# %matplotlib inline

# %%
axis1 = plt.subplot2grid((6,1),(0,0),rowspan=5,colspan=1)
axis2 = plt.subplot2grid((6,1),(5,0),rowspan=1,colspan=1)
axis1.plot(df.index,df['Adj Close'])
axis2.plot(df.index,df['Volume'])

# %%
axis1.plot(df.index,df['Adj Close'])
axis2.plot(df.index,df['Volume'])
plt.show()

# %%
df['ma5'] = df['Open'].rolling(window=5, min_periods=1).mean()

# %%
df.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Close</th>
#       <th>Adj Close</th>
#       <th>Volume</th>
#       <th>ma5</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-06-29</th>
#       <td>19.000000</td>
#       <td>25.00</td>
#       <td>17.540001</td>
#       <td>23.889999</td>
#       <td>23.889999</td>
#       <td>18766300</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <th>2010-06-30</th>
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2034 entries, 2010-06-29 to 2018-07-26
# Data columns (total 10 columns):
# Open          2034 non-null float64
# High          2034 non-null float64
# Low           2034 non-null float64
# Close         2034 non-null float64
# Adj Close     2034 non-null float64
# Volume        2034 non-null int64
# ma5           2034 non-null float64
# dayofweek     2034 non-null int64
# weekofyear    2034 non-null int64
# datenew       2034 non-null float64
# dtypes: float64(7), int64(3)
# memory usage: 254.8 KB

# %%
df_ohlc = df[['Open','Close']].resample('W').ohlc()

# %%
# df['datenew']=df.index.map(lambda x:x-Day(2))

# %%
df.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Close</th>
#       <th>Adj Close</th>
#       <th>Volume</th>
#       <th>ma5</th>
#       <th>dayofweek</th>
#       <th>weekofyear</th>
#       <th>datenew</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-06-29</th>
#       <td>19.000000</td>
#       <td>25.00</td>
#       <td>17.540001</td>
#       <td>23.889999</td>
# ...

# %%
df_ohlc.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="4" halign="left">Open</th>
#       <th colspan="4" halign="left">Close</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>open</th>
#       <th>high</th>
#       <th>low</th>
#       <th>close</th>
#       <th>open</th>
#       <th>high</th>
#       <th>low</th>
#       <th>close</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-07-04</th>
#       <td>19.000000</td>
#       <td>25.790001</td>
#       <td>19.000000</td>
# ...

# %%
df_ohlc.columns
# Out:
# MultiIndex(levels=[['Open', 'Close'], ['open', 'high', 'low', 'close']],
#            labels=[[0, 0, 0, 0, 1, 1, 1, 1], [0, 1, 2, 3, 0, 1, 2, 3]])

# %%
l = df_ohlc['Open']['open']
h = df_ohlc['Close']['close']
df_c = pd.DataFrame(index=df_ohlc.index)

# %%
df_c['l']=l
df_c['h']=h
df_c['re']=( df_c['h'] - df_c['l'] ) / df_c['l']

# %%
df_c.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>l</th>
#       <th>h</th>
#       <th>re</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-07-04</th>
#       <td>19.000000</td>
#       <td>19.200001</td>
#       <td>0.010526</td>
#     </tr>
#     <tr>
#       <th>2010-07-11</th>
#       <td>20.000000</td>
#       <td>17.400000</td>
#       <td>-0.130000</td>
#     </tr>
#     <tr>
#       <th>2010-07-18</th>
#       <td>17.950001</td>
#       <td>20.639999</td>
#       <td>0.149861</td>
#     </tr>
#     <tr>
#       <th>2010-07-25</th>
# ...

# %%
df.head(15)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Close</th>
#       <th>Adj Close</th>
#       <th>Volume</th>
#       <th>ma5</th>
#       <th>dayofweek</th>
#       <th>weekofyear</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2010-06-29</th>
#       <td>19.000000</td>
#       <td>25.000000</td>
#       <td>17.540001</td>
#       <td>23.889999</td>
#       <td>23.889999</td>
# ...

# %%
df['dayofweek'] = df.index.dayofweek
df['weekofyear'] = df.index.weekofyear

# %%
df.tail(15)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Close</th>
#       <th>Adj Close</th>
#       <th>Volume</th>
#       <th>ma5</th>
#       <th>dayofweek</th>
#       <th>weekofyear</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2018-07-06</th>
#       <td>304.950012</td>
#       <td>312.070007</td>
#       <td>302.000000</td>
#       <td>308.899994</td>
#       <td>308.899994</td>
# ...

# %%
df.groupby(['weekofyear','dayofweek'])['Open'].max()
# Out:
# weekofyear  dayofweek
# 1           0            230.720001
#             1            312.000000
#             2            321.000000
#             3            312.869995
#             4            316.619995
# 2           0            316.000000
#             1            335.160004
#             2            332.200012
#             3            335.239990
#             4            338.630005
# 3           0            203.050003
#             1            337.540009
#             2            340.470001
#             3            345.670013
#             4            345.000000
# 4           0            349.399994
#             1            360.000000
#             2            354.579987
#             3            348.269989
#             4            341.500000
# 5           0            339.850006
#             1            345.140015
#             2            347.510010
#             3            351.000000
#             4            348.440002
# ...

# %%
df['Open'].max()
# Out:
# 386.69000199999999

# %%
df_wk = web.DataReader('000002.ss','yahoo',start=start,end=end)

# %%
df_wk.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Close</th>
#       <th>Adj Close</th>
#       <th>Volume</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-05-02</th>
#       <td>2272.100098</td>
#       <td>2281.429932</td>
#       <td>2262.080078</td>
#       <td>2275.669922</td>
#       <td>2275.669922</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2013-05-03</th>
#       <td>2280.840088</td>
#       <td>2326.570068</td>
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
df_y = pd.read_excel('data/returnrate data/SH600000.xlsx',
                     index_col=0,header=0,names=['company'])

# %%
df_y['company'] = df_y['company'].map(np.exp)

# %%
df_x = pd.read_excel('data/sh300returnrate.xlsx',
                     index_col=0,header=0,names=['market'])

# %%
df_x['market'] = df_x['market'].map(np.exp)

# %%
df = pd.concat([df_x,df_y],axis=1,join='outer',join_axes=[df_y.index])

# %%
df = df.replace([np.inf,-np.inf],np.nan)

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>market</th>
#       <th>company</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2005-04-17</th>
#       <td>0.970731</td>
#       <td>1.041322</td>
#     </tr>
#     <tr>
#       <th>2005-04-24</th>
#       <td>0.964089</td>
#       <td>1.039683</td>
#     </tr>
#     <tr>
#       <th>2005-05-01</th>
#       <td>0.992866</td>
#       <td>0.990467</td>
#     </tr>
#     <tr>
#       <th>2005-05-15</th>
#       <td>0.951888</td>
#       <td>1.007692</td>
#     </tr>
#     <tr>
#       <th>2005-05-22</th>
#       <td>0.994614</td>
# ...

# %%
df = df.dropna(axis=0)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(df['market'][0:15],df['conpany'][0:15],"*")

# %%
x = df[['market']][50:80]

# %%
y = df['conpany'][50:80]

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
risk_free = 1 + 3.654/100

# %%
type(df['market'])
# Out:
# pandas.core.series.Series

# %%
def lireg(x,y):
    x=x-risk_free
    y=y-risk_free
    model = LinearRegression()
    model.fit(x,y)
    return model.intercept_

# %%
lireg(df[['market']],df['conpany'])
# Out:
# -0.01523582239818282

# %%
linreg(df['market'],df['conpany'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-190-1aae067b110a> in <module>()
# ----> 1 linreg(df['market'],df['conpany'])
#
# <ipython-input-189-fadb0e3c65c2> in linreg(x, y)
#       3     from sklearn.linear_model import LinearRegression
#       4     model = LinearRegression()
# ----> 5     model.fit(x-risk_free,y-risk_free)
#       6     return model.intercept_
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
 df_cal = df.resample('Q').apply(lambda x:linreg(x[['market']],x['company']))

# %%
df_cal
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>market</th>
#       <th>company</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2005-06-30</th>
#       <td>-0.074258</td>
#       <td>-0.074258</td>
#     </tr>
#     <tr>
#       <th>2005-09-30</th>
#       <td>-0.094627</td>
#       <td>-0.094627</td>
#     </tr>
#     <tr>
#       <th>2005-12-31</th>
#       <td>-0.130291</td>
#       <td>-0.130291</td>
#     </tr>
#     <tr>
#       <th>2006-03-31</th>
#       <td>-0.228279</td>
#       <td>-0.228279</td>
#     </tr>
#     <tr>
#       <th>2006-06-30</th>
# ...

# %%
df_alpha = df_cal.drop(['market'],axis=1)

# %%
df_alpha.rename(columns={'company':'alpha'},inplace=True)

# %%
df_alpha.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>alpha</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2005-04-17</th>
#       <td>0.004782</td>
#     </tr>
#     <tr>
#       <th>2005-06-26</th>
#       <td>-0.075745</td>
#     </tr>
#     <tr>
#       <th>2005-09-04</th>
#       <td>-0.082478</td>
#     </tr>
#     <tr>
#       <th>2005-11-13</th>
#       <td>-0.143840</td>
#     </tr>
#     <tr>
#       <th>2006-01-22</th>
#       <td>-0.173054</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_alpha.to_excel('data/alpha/SH600000.xlsx')

# %%
df_cal['dayofweek'] = df_cal.index.dayofweek

# %%
k = df[['market']]

# %%
type(k)
# Out:
# pandas.core.frame.DataFrame

# %%
df_cal = df.resample('10W')

# %%
df_cal
# Out:
# DatetimeIndexResampler [freq=<10 * Weeks: weekday=6>, axis=0, closed=right, label=right, convention=start, base=0]

# %%
type(df['market']])
# Out:
# list

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-41389fad42b5> in <module>()
# ----> 1 import tensorflow as tf
#
# ImportError: No module named 'tensorflow'
