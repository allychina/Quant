# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import datetime as dt
from matplotlib import style
import numpy as np
# import xlrd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-f289ead5c6dd> in <module>()
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 import pandas_datareader.data as web
#       4 import datetime as dt
#       5 from matplotlib import style
#
# ImportError: No module named 'pandas_datareader'

# %%
columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Turnover']

# %%
f = pd.read_excel('/Users/ally/AI/data/SH600887.xlsx', header=None, names=columns, skiprows=[0,1])

# %%
f = f.set_index('Date')

# %%
f.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Close</th>
#       <th>Volume</th>
#       <th>Turnover</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2000-01-04</th>
#       <td>-1.76</td>
#       <td>-1.76</td>
#       <td>-1.79</td>
#       <td>-1.76</td>
#       <td>435500</td>
#       <td>8800997</td>
#     </tr>
#     <tr>
#       <th>2000-01-05</th>
#       <td>-1.75</td>
#       <td>-1.73</td>
#       <td>-1.78</td>
# ...

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4386 entries, 2000-01-04 to 2018-07-19
# Data columns (total 6 columns):
# Open        4386 non-null float64
# High        4386 non-null float64
# Low         4386 non-null float64
# Close       4386 non-null float64
# Volume      4386 non-null int64
# Turnover    4386 non-null int64
# dtypes: float64(4), int64(2)
# memory usage: 239.9 KB

# %%
f['dayofweek'] = f.index.dayofweek

# %%
f.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Close</th>
#       <th>Volume</th>
#       <th>Turnover</th>
#       <th>dayofweek</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2000-01-04</th>
#       <td>-1.76</td>
#       <td>-1.76</td>
#       <td>-1.79</td>
#       <td>-1.76</td>
#       <td>435500</td>
#       <td>8800997</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2000-01-05</th>
#       <td>-1.75</td>
# ...

# %%
f['shift1'] = f['Close'].shift(1)

# %%
# f= f.drop(['Open','High','Low','Volume','Turnover'], axis=1)

# %%
f.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Close</th>
#       <th>Volume</th>
#       <th>Turnover</th>
#       <th>dayofweek</th>
#       <th>shift1</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2000-01-04</th>
#       <td>-1.76</td>
#       <td>-1.76</td>
#       <td>-1.79</td>
#       <td>-1.76</td>
#       <td>435500</td>
#       <td>8800997</td>
#       <td>1</td>
#       <td>NaN</td>
#     </tr>
# ...

# %%
f['returnofday'] = f.apply(lambda x:np.log(x['Close']/x['shift1']), axis=1)
# Out:
# /Users/ally/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in log
#   if __name__ == '__main__':
# /Users/ally/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':
# /Users/ally/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in double_scalars
#   if __name__ == '__main__':
# /Users/ally/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in double_scalars
#   if __name__ == '__main__':

# %%
f.head(15)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Close</th>
#       <th>Volume</th>
#       <th>Turnover</th>
#       <th>dayofweek</th>
#       <th>shift1</th>
#       <th>returnofday</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2000-01-04</th>
#       <td>-1.76</td>
#       <td>-1.76</td>
#       <td>-1.79</td>
#       <td>-1.76</td>
#       <td>435500</td>
#       <td>8800997</td>
# ...

# %%
f_cal = f['returnofday'].resample('W').mean()*5

# %%
f_cal = pd.DataFrame(f_cal)

# %%
f_cal
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>returnofday</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2000-01-09</th>
#       <td>-1.075642e-01</td>
#     </tr>
#     <tr>
#       <th>2000-01-16</th>
#       <td>6.453852e-02</td>
#     </tr>
#     <tr>
#       <th>2000-01-23</th>
#       <td>-7.061757e-02</td>
#     </tr>
#     <tr>
#       <th>2000-01-30</th>
#       <td>6.079046e-03</td>
#     </tr>
#     <tr>
#       <th>2000-02-06</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2000-02-13</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2000-02-20</th>
# ...
